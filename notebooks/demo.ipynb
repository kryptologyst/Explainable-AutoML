# %% [markdown]
# # Explainable AutoML Demo
#
# This notebook demonstrates the Explainable AutoML framework with the Iris dataset.
#
# **Author**: kryptologyst
# **GitHub**: https://github.com/kryptologyst
#
# ⚠️ **Safety Disclaimer**: This is a research/educational tool. Not for production decisions or control.
